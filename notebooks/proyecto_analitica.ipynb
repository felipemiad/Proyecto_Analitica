# %% [markdown]
# # Proyecto de Análisis de Datos
# Este notebook está dividido en secciones específicas para que cada colaborador realice su tarea asignada.

# %% [markdown]
# # Importar librerias necesarias (Laura)

# %%
import pandas as pd

# %% [markdown]
# # Crear el DF (Laura)

# %%
df_2022 = pd.read_csv("data/df_2022.csv")
df_2022
# Out:
#       ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO ESTU_FECHANACIMIENTO  \
# 0                     CC          COLOMBIA           F           2004-01-27
# 1                     CC          COLOMBIA           M           2002-06-23
# 2                     CC          COLOMBIA           F           2001-06-06
# 3                     TI          COLOMBIA           M           2005-02-17
# 4                     TI          COLOMBIA           F           2006-02-04
# ...                  ...               ...         ...                  ...
# 53274                 TI          COLOMBIA           F           2004-04-30
# 53275                 TI          COLOMBIA           M           2005-04-13
# 53276                 TI          COLOMBIA           M           2005-05-07
# 53277                 CC          COLOMBIA           M           2004-01-11
# 53278                 TI          COLOMBIA           F           2005-11-06
#
#        PERIODO  ESTU_CONSECUTIVO ESTU_ESTUDIANTE ESTU_PAIS_RESIDE  \
# 0        20224  SB11202240382159      ESTUDIANTE         COLOMBIA
# 1        20224  SB11202240388303      ESTUDIANTE         COLOMBIA
# 2        20224  SB11202240564961      ESTUDIANTE         COLOMBIA
# 3        20224  SB11202240526792      ESTUDIANTE         COLOMBIA
# 4        20224  SB11202240088017      ESTUDIANTE         COLOMBIA
# ...        ...               ...             ...              ...
# 53274    20224  SB11202240210685      ESTUDIANTE         COLOMBIA
# 53275    20224  SB11202240183732      ESTUDIANTE         COLOMBIA
# 53276    20224  SB11202240017373      ESTUDIANTE         COLOMBIA
# 53277    20224  SB11202240506805      ESTUDIANTE         COLOMBIA
# 53278    20224  SB11202240417199      ESTUDIANTE         COLOMBIA
#
#       ESTU_TIENEETNIA ESTU_DEPTO_RESIDE  ...  PUNT_SOCIALES_CIUDADANAS  \
# 0                  Si             CHOCO  ...                        24
# 1                  Si             SUCRE  ...                        25
# 2                  Si         RISARALDA  ...                        23
# 3                  Si             CESAR  ...                        19
# 4                  Si             CAUCA  ...                        32
# ...               ...               ...  ...                       ...
# 53274              No             SUCRE  ...                        34
# 53275              No             SUCRE  ...                        33
# 53276              No             SUCRE  ...                        39
# 53277              No             SUCRE  ...                        38
# 53278              No             SUCRE  ...                        48
#
#       DESEMP_SOCIALES_CIUDADANAS  PERCENTIL_SOCIALES_CIUDADANAS PUNT_GLOBAL  \
# 0                              1                              1         147
# 1                              1                              1         144
# 2                              1                              1         147
# 3                              1                              1         138
# 4                              1                             10         142
# ...                          ...                            ...         ...
# 53274                          1                             14         218
# 53275                          1                             12         176
# 53276                          1                             28         205
# 53277                          1                             26         162
# 53278                          2                             53         258
#
#       PERCENTIL_GLOBAL PERCENTIL_ESPECIAL_GLOBAL ESTU_INSE_INDIVIDUAL  \
# 0                  1.0                       1.0                  NaN
# 1                  1.0                       1.0                  NaN
# 2                  1.0                       1.0         4.938466e+14
# 3                  NaN                       1.0         3.884057e+14
# 4                  1.0                       1.0         4.373906e+14
# ...                ...                       ...                  ...
# 53274             31.0                       NaN         5.036176e+14
# 53275              7.0                       NaN         5.392192e+14
# 53276             22.0                       NaN         4.540895e+14
# 53277              2.0                       NaN                  NaN
# 53278             57.0                       NaN         4.050697e+13
#
#       ESTU_NSE_INDIVIDUAL ESTU_NSE_ESTABLECIMIENTO ESTU_ESTADOINVESTIGACION
# 0                     NaN                      2.0                 PUBLICAR
# 1                     NaN                      2.0                 PUBLICAR
# 2                     2.0                      2.0                 PUBLICAR
# 3                     1.0                      2.0                 PUBLICAR
# 4                     2.0                      2.0                 PUBLICAR
# ...                   ...                      ...                      ...
# 53274                 2.0                      2.0                 PUBLICAR
# 53275                 3.0                      3.0                 PUBLICAR
# 53276                 2.0                      3.0                 PUBLICAR
# 53277                 NaN                      2.0                 PUBLICAR
# 53278                 1.0                      1.0                 PUBLICAR
#
# [53279 rows x 81 columns]

# %% [markdown]
# # Nuevo df con Lista de variables (Jorge)

# %%
# Lista con variables de interés (se escogen 24 inicialmente como las que podrían ser interesantes). Esto se hace no solo por el hecho de creer que podrían ser inyteresantes, sino que hay algunas variables con información repetitiva y no relevante, como por ejemplo, municipio y código de municipio (solo sería suficiente con tener el municipio).
variables_iniciales = ["ESTU_GENERO","ESTU_DEPTO_RESIDE","FAMI_EDUCACIONPADRE","FAMI_EDUCACIONMADRE","FAMI_ESTRATOVIVIENDA","FAMI_PERSONASHOGAR","FAMI_TIENEINTERNET","FAMI_TIENECONSOLAVIDEOJUEGOS","FAMI_NUMLIBROS","ESTU_HORASSEMANATRABAJA","FAMI_COMELECHEDERIVADOS","FAMI_COMECARNEPESCADOHUEVO","COLE_JORNADA","COLE_GENERO","COLE_NATURALEZA","COLE_BILINGUE","COLE_CARACTER","COLE_AREA_UBICACION","PUNT_MATEMATICAS","PUNT_INGLES","PUNT_C_NATURALES","PUNT_LECTURA_CRITICA","PUNT_SOCIALES_CIUDADANAS","PUNT_GLOBAL"]
#Nuevos DataFrame con las 24 variables seleccionadas
new_2022 = df_2022[variables_iniciales]
new_2022
# Out:
#       ESTU_GENERO ESTU_DEPTO_RESIDE                   FAMI_EDUCACIONPADRE  \
# 0               F             CHOCO                                   NaN
# 1               M             SUCRE                                   NaN
# 2               F         RISARALDA    Secundaria (Bachillerato) completa
# 3               M             CESAR  Secundaria (Bachillerato) incompleta
# 4               F             CAUCA  Secundaria (Bachillerato) incompleta
# ...           ...               ...                                   ...
# 53274           F             SUCRE                               Ninguno
# 53275           M             SUCRE                               No sabe
# 53276           M             SUCRE                                   NaN
# 53277           M             SUCRE                                   NaN
# 53278           F             SUCRE                   Primaria incompleta
#
#                         FAMI_EDUCACIONMADRE FAMI_ESTRATOVIVIENDA  \
# 0                                       NaN                  NaN
# 1                                       NaN                  NaN
# 2            Técnica o tecnológica completa            Estrato 1
# 3                         Primaria completa            Estrato 1
# 4                                   Ninguno          Sin Estrato
# ...                                     ...                  ...
# 53274                     Primaria completa                  NaN
# 53275                               No sabe            Estrato 3
# 53276                                   NaN                  NaN
# 53277                                   NaN                  NaN
# 53278  Secundaria (Bachillerato) incompleta            Estrato 1
#
#       FAMI_PERSONASHOGAR FAMI_TIENEINTERNET FAMI_TIENECONSOLAVIDEOJUEGOS  \
# 0                  3 a 4                NaN                          NaN
# 1                    NaN                NaN                          NaN
# 2                9 o más                 Si                           No
# 3                9 o más                 No                           No
# 4                  3 a 4                 No                           No
# ...                  ...                ...                          ...
# 53274            9 o más                 Si                           No
# 53275              3 a 4                 Si                           No
# 53276              3 a 4                NaN                           No
# 53277                NaN                NaN                          NaN
# 53278              5 a 6                 No                           No
#
#           FAMI_NUMLIBROS ESTU_HORASSEMANATRABAJA  ... COLE_NATURALEZA  \
# 0                    NaN                     NaN  ...         OFICIAL
# 1                    NaN                     NaN  ...         OFICIAL
# 2      MÁS DE 100 LIBROS         Más de 30 horas  ...         OFICIAL
# 3         11 A 25 LIBROS       Menos de 10 horas  ...         OFICIAL
# 4          0 A 10 LIBROS       Menos de 10 horas  ...         OFICIAL
# ...                  ...                     ...  ...             ...
# 53274    26 A 100 LIBROS       Menos de 10 horas  ...         OFICIAL
# 53275     11 A 25 LIBROS       Menos de 10 horas  ...      NO OFICIAL
# 53276                NaN                       0  ...      NO OFICIAL
# 53277                NaN                     NaN  ...      NO OFICIAL
# 53278                NaN       Menos de 10 horas  ...         OFICIAL
#
#       COLE_BILINGUE      COLE_CARACTER COLE_AREA_UBICACION PUNT_MATEMATICAS  \
# 0               NaN                NaN               RURAL               26
# 1               NaN          NO APLICA               RURAL               24
# 2                 N  TÉCNICO/ACADÉMICO               RURAL               27
# 3                 N  TÉCNICO/ACADÉMICO              URBANO               28
# 4                 S  TÉCNICO/ACADÉMICO               RURAL               18
# ...             ...                ...                 ...              ...
# 53274             N  TÉCNICO/ACADÉMICO              URBANO               46
# 53275             N          ACADÉMICO              URBANO               30
# 53276             N          ACADÉMICO              URBANO               38
# 53277             N          ACADÉMICO              URBANO               26
# 53278             N  TÉCNICO/ACADÉMICO              URBANO               51
#
#       PUNT_INGLES PUNT_C_NATURALES PUNT_LECTURA_CRITICA  \
# 0            38.0               33                   32
# 1            35.0               29                   35
# 2            31.0               35                   32
# 3             NaN               31                   32
# 4            34.0               30                   32
# ...           ...              ...                  ...
# 53274        46.0               41                   53
# 53275        44.0               42                   33
# 53276        38.0               36                   52
# 53277        40.0               34                   29
# 53278        36.0               50                   63
#
#        PUNT_SOCIALES_CIUDADANAS  PUNT_GLOBAL
# 0                            24          147
# 1                            25          144
# 2                            23          147
# 3                            19          138
# 4                            32          142
# ...                         ...          ...
# 53274                        34          218
# 53275                        33          176
# 53276                        39          205
# 53277                        38          162
# 53278                        48          258
#
# [53279 rows x 24 columns]

# %% [markdown]
# # Preprocesamiento y descriptivo (Jorge)

# %%
#Calcular datos faltantes
def contar_faltantes(dataframe, lista):
    dicc_cont_faltantes = {}
    for i in lista:
        datos_faltantes = dataframe[i].isna().sum()
        dicc_cont_faltantes[i] = datos_faltantes
    return dicc_cont_faltantes
print("A continuación está el diccionario con los faltantes de la base 2022")
print(contar_faltantes(new_2022, variables_iniciales))

df_total=new_2022
#Eliminar las columnas que tienen más del 10% de datos faltantes, ya que eliminar las filas correspondientes sería perder tamaño en los datos, e imputar datos no es considerado para las variables dadas una buena opción ya que puede distorsionar el análisis descriptivo de los datos debido a la gran cantidad de datos faltantes.
#Por otro lado, para las columnas con menos de 10% de datos faltantes, se decide imputar los datos con la moda para variables categóricas en las que aplique, y con la media para variables numéricas en las que aplique.
diccionario = contar_faltantes(df_total, variables_iniciales)
columnas_a_eliminar = [llave for llave, valor in diccionario.items() if valor > 0.10*len(df_total)]
df_definitivo = df_total.drop(columns=columnas_a_eliminar)
imputar_moda = ['ESTU_GENERO','ESTU_DEPTO_RESIDE','FAMI_EDUCACIONPADRE','FAMI_EDUCACIONMADRE','FAMI_ESTRATOVIVIENDA','FAMI_TIENEINTERNET','FAMI_TIENECONSOLAVIDEOJUEGOS','ESTU_HORASSEMANATRABAJA','FAMI_NUMLIBROS','FAMI_PERSONASHOGAR','COLE_JORNADA','COLE_GENERO','COLE_NATURALEZA','COLE_CARACTER','COLE_AREA_UBICACION','FAMI_COMELECHEDERIVADOS','FAMI_COMECARNEPESCADOHUEVO']
imputar_media = ['PUNT_MATEMATICAS','PUNT_INGLES','PUNT_C_NATURALES','PUNT_LECTURA_CRITICA','PUNT_SOCIALES_CIUDADANAS','PUNT_GLOBAL']
for columna in imputar_moda:
    moda = df_definitivo[columna].mode()[0]
    df_definitivo[columna] = df_definitivo[columna].fillna(moda)
for columna in imputar_media:
    media = df_definitivo[columna].mean()
    df_definitivo[columna] = df_definitivo[columna].fillna(media)
df_definitivo


nombres_columnas = df_definitivo.columns.tolist()
diccionario2 = contar_faltantes(df_definitivo, nombres_columnas)
print(diccionario2) #Verifiqué que ya no hay datos nulos en el dataframe final.
print(len(df_definitivo)) #El dataframe final queda con 53279 observaciones y 23 columnas.
tipos_datos = df_definitivo.dtypes #Validar el tipo de datos.
print(tipos_datos)
# Out:
# A continuación está el diccionario con los faltantes de la base 2022
# {'ESTU_GENERO': 1, 'ESTU_DEPTO_RESIDE': 0, 'FAMI_EDUCACIONPADRE': 3077, 'FAMI_EDUCACIONMADRE': 3097, 'FAMI_ESTRATOVIVIENDA': 3539, 'FAMI_PERSONASHOGAR': 2304, 'FAMI_TIENEINTERNET': 3159, 'FAMI_TIENECONSOLAVIDEOJUEGOS': 2471, 'FAMI_NUMLIBROS': 4630, 'ESTU_HORASSEMANATRABAJA': 2393, 'FAMI_COMELECHEDERIVADOS': 3658, 'FAMI_COMECARNEPESCADOHUEVO': 3229, 'COLE_JORNADA': 0, 'COLE_GENERO': 0, 'COLE_NATURALEZA': 0, 'COLE_BILINGUE': 9707, 'COLE_CARACTER': 2099, 'COLE_AREA_UBICACION': 0, 'PUNT_MATEMATICAS': 0, 'PUNT_INGLES': 193, 'PUNT_C_NATURALES': 0, 'PUNT_LECTURA_CRITICA': 0, 'PUNT_SOCIALES_CIUDADANAS': 0, 'PUNT_GLOBAL': 0}
# {'ESTU_GENERO': 0, 'ESTU_DEPTO_RESIDE': 0, 'FAMI_EDUCACIONPADRE': 0, 'FAMI_EDUCACIONMADRE': 0, 'FAMI_ESTRATOVIVIENDA': 0, 'FAMI_PERSONASHOGAR': 0, 'FAMI_TIENEINTERNET': 0, 'FAMI_TIENECONSOLAVIDEOJUEGOS': 0, 'FAMI_NUMLIBROS': 0, 'ESTU_HORASSEMANATRABAJA': 0, 'FAMI_COMELECHEDERIVADOS': 0, 'FAMI_COMECARNEPESCADOHUEVO': 0, 'COLE_JORNADA': 0, 'COLE_GENERO': 0, 'COLE_NATURALEZA': 0, 'COLE_CARACTER': 0, 'COLE_AREA_UBICACION': 0, 'PUNT_MATEMATICAS': 0, 'PUNT_INGLES': 0, 'PUNT_C_NATURALES': 0, 'PUNT_LECTURA_CRITICA': 0, 'PUNT_SOCIALES_CIUDADANAS': 0, 'PUNT_GLOBAL': 0}
# 53279
# ESTU_GENERO                      object
# ESTU_DEPTO_RESIDE                object
# FAMI_EDUCACIONPADRE              object
# FAMI_EDUCACIONMADRE              object
# FAMI_ESTRATOVIVIENDA             object
# FAMI_PERSONASHOGAR               object
# FAMI_TIENEINTERNET               object
# FAMI_TIENECONSOLAVIDEOJUEGOS     object
# FAMI_NUMLIBROS                   object
# ESTU_HORASSEMANATRABAJA          object
# FAMI_COMELECHEDERIVADOS          object
# FAMI_COMECARNEPESCADOHUEVO       object
# COLE_JORNADA                     object
# COLE_GENERO                      object
# COLE_NATURALEZA                  object
# COLE_CARACTER                    object
# COLE_AREA_UBICACION              object
# PUNT_MATEMATICAS                  int64
# PUNT_INGLES                     float64
# PUNT_C_NATURALES                  int64
# PUNT_LECTURA_CRITICA              int64
# PUNT_SOCIALES_CIUDADANAS          int64
# PUNT_GLOBAL                       int64
# dtype: object
